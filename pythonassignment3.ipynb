# %%
def triangle(s1, s2, s3):
    if s1**2 + s2**2 == s3**2:
        print ("It is a right angled triangle.")
    elif s1**2 + s3**2 == s2**2:
        print("It is a right angled triangle.")
    elif s2**2 + s3**2 == s1**2:
        print("It is a right angled triangle.")
    else: 
        print("It is not a right angled triangle.")
s1=int(input("enter the length of the first side: "))
s2=int(input("Enter the length of the second side: "))
s3=int(input("Enter the length of the third side: "))
triangle(s1, s2, s3)
# Out:
# enter the length of the first side:  45
# Enter the length of the second side:  78
# Enter the length of the third side:  90
# It is not a right angled triangle.

# %% [markdown]
# # Assistant
# This error occurs because Python requires proper indentation for code blocks. In Python, statements inside `if`, `elif`, `else`, and function definitions must be indented (usually 4 spaces or 1 tab). Additionally, there are some other syntax errors in your code:
#
# 1. **IndentationError**: The `print` statements are not properly indented
# 2. **NameError**: `S1` should be `s1` (case-sensitive)
# 3. **SyntaxError**: Missing closing parentheses in the `input()` statements
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# This error occurs because Python requires proper indentation for code blocks. In Python, statements inside `if`, `elif`, `else`, and function definitions must be indented (usually 4 spaces or 1 tab). Additionally, there are some other syntax errors in your code:
#
# 1. **IndentationError**: The `print` statements are not properly indented
# 2. **NameError**: `S1` should be `s1` (case-sensitive)
# 3. **SyntaxError**: Missing closing parentheses in the `input()` statements
#
# Would you like me to provide the corrected code?
